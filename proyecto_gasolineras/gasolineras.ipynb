# %%
import requests
import json

# %%
url = 'https://sedeaplicaciones.minetur.gob.es/ServiciosRESTCarburantes/PreciosCarburantes/EstacionesTerrestres/'

# %%
#Importamos los datos de la  url
r = requests.get(url)

# %%
#Leemos los datos
datos = r.json()

# %%
#Nos quedamos con ListaEESSPrecio
datos = datos['ListaEESSPrecio']

# %%
#Lo pasamos a dataframe
import pandas as pd
df = pd.DataFrame(datos)

# %%
df
# Out:
#         C.P.                                          Dirección  \
# 0      02250                     AVENIDA CASTILLA LA MANCHA, 26
# 1      02001                     CALLE FEDERICO GARCIA LORCA, 1
# 2      02001                     CALLE FEDERICO GARCIA LORCA, 5
# 3      02001                            AVENIDA 1º DE MAYO, S/N
# 4      02001  CALLE PRINCIPE DE ASTURIAS (POLÍGONO DE ROMICA...
# ...      ...                                                ...
# 11802  50197                 RONDA FERIA DE MUESTRAS, DE LA, 20
# 11803  50197                         POLIGONO CALLE TURIASO, 31
# 11804  50800                        CARRETERA N-330A KM. 24,000
# 11805  50800                               CALLE AUSTRIA, 11,17
# 11806  50810                               CALLE COOPERATIVA, 2
#
#                                 Horario    Latitud        Localidad  \
# 0                      L-D: 07:00-22:00  39,211417        ABENGIBRE
# ...

# %%
# Out:
# list

# %%
datos
# Out:
# [{'C.P.': '02250',
#   'Dirección': 'AVENIDA CASTILLA LA MANCHA, 26',
#   'Horario': 'L-D: 07:00-22:00',
#   'Latitud': '39,211417',
#   'Localidad': 'ABENGIBRE',
#   'Longitud (WGS84)': '-1,539167',
#   'Margen': 'D',
#   'Municipio': 'Abengibre',
#   'Precio Biodiesel': '',
#   'Precio Bioetanol': '',
#   'Precio Gas Natural Comprimido': '',
#   'Precio Gas Natural Licuado': '',
#   'Precio Gases licuados del petróleo': '',
#   'Precio Gasoleo A': '1,639',
#   'Precio Gasoleo B': '1,190',
#   'Precio Gasoleo Premium': '',
#   'Precio Gasolina 95 E10': '',
#   'Precio Gasolina 95 E5': '1,589',
#   'Precio Gasolina 95 E5 Premium': '',
#   'Precio Gasolina 98 E10': '',
#   'Precio Gasolina 98 E5': '',
#   'Precio Hidrogeno': '',
#   'Provincia': 'ALBACETE',
#   'Remisión': 'dm',
#   'Rótulo': 'Nº 10.935',
#   'Tipo Venta': 'P',
#   '% BioEtanol': '0,0',
#   '% Éster metílico': '0,0',
#   'IDEESS': '4375',
#   'IDMunicipio': '52',
#   'IDProvincia': '02',
#   'IDCCAA': '07'},
# ...

# %%
#Guardamos los datos en un json
with open('gas.json', 'w') as f:
    json.dump(datos, f)

# %%
data = json.load(open('gas.json'))

# %%
data1 = data[1]

# %%
type(data1)
# Out:
# dict

# %%
db.child("gasolineras").set(data1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6232/1343242772.py in <module>
# ----> 1 db.child("gasolineras").set(data1)
#
# NameError: name 'db' is not defined

# %%
def getdata():
  url = 'https://sedeaplicaciones.minetur.gob.es/ServiciosRESTCarburantes/PreciosCarburantes/EstacionesTerrestres/'
  r = requests.get(url)
  datos = r.json()
  datos = datos['ListaEESSPrecio']
  df = pd.DataFrame(datos)
  print('Done!')

# %%
getdata()
# Out:
# Done!

# %%
def getgasol():
    url = 'https://sedeaplicaciones.minetur.gob.es/ServiciosRESTCarburantes/PreciosCarburantes/EstacionesTerrestres/'
    try:
        r = requests.get(url)
    except:
        print('Error')
    try:
        datos = r.json()
    except:
        print('Error en json')
    try:
        datos = datos['ListaEESSPrecio']
    except:
        print('Error en datos')
    try:
        df = pd.DataFrame(datos)
    except:
        print('Error en dataframe')
    print('Done!')

# %%
getgasol()
# Out:
# Done!
